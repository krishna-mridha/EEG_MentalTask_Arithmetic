# %%
import pyedflib
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
#file_name = os.path.join(pyedflib.util.test_data_path(),'Subject00_1.edf')
f = pyedflib.EdfReader('Subject00_2.edf')
n = f.signals_in_file
signal_labels = f.getSignalLabels()
sigbufs = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
    sigbufs[i, :] = f.readSignal(i)
    
f.close()

# %%
print(sigbufs)
# Out:
# [[ 4.47604913e+00  1.20802117e+00 -2.54600773e+00 ... -4.13607233e-04
#   -4.13607233e-04 -4.13607233e-04]
#  [-2.74030294e+00 -3.30875398e+00 -3.70825978e+00 ... -1.40245823e-03
#   -1.40245823e-03 -1.40245823e-03]
#  [-2.50173872e+00 -4.41783471e+00 -6.41085425e+00 ...  2.52872511e-05
#    2.52872511e-05  2.52872511e-05]
#  ...
#  [ 8.48305957e-01  4.52614272e-01 -1.03927692e-01 ... -9.83513695e-04
#   -9.83513695e-04 -9.83513695e-04]
#  [ 9.30096361e-02 -2.64323612e-01 -4.21048721e-01 ...  2.28371710e-04
#    2.28371710e-04  2.28371710e-04]
#  [-8.46279094e-03 -8.37301808e-03 -8.47401254e-03 ...  9.52217899e-06
#    9.52217899e-06  9.52217899e-06]]

# %%
sigbufs
# Out:
# array([[ 4.47604913e+00,  1.20802117e+00, -2.54600773e+00, ...,
#         -4.13607233e-04, -4.13607233e-04, -4.13607233e-04],
#        [-2.74030294e+00, -3.30875398e+00, -3.70825978e+00, ...,
#         -1.40245823e-03, -1.40245823e-03, -1.40245823e-03],
#        [-2.50173872e+00, -4.41783471e+00, -6.41085425e+00, ...,
#          2.52872511e-05,  2.52872511e-05,  2.52872511e-05],
#        ...,
#        [ 8.48305957e-01,  4.52614272e-01, -1.03927692e-01, ...,
#         -9.83513695e-04, -9.83513695e-04, -9.83513695e-04],
#        [ 9.30096361e-02, -2.64323612e-01, -4.21048721e-01, ...,
#          2.28371710e-04,  2.28371710e-04,  2.28371710e-04],
#        [-8.46279094e-03, -8.37301808e-03, -8.47401254e-03, ...,
#          9.52217899e-06,  9.52217899e-06,  9.52217899e-06]])

# %%
plt.plot(sigbufs[1,1:3000])
plt.show()

# %%
plt.plot(sigbufs[0])
plt.show()

# %%
sigbufs[1,:].shape
# Out:
# (31000,)

# %%
n
# Out:
# 21

# %%
len(signal_labels)
# Out:
# 21

# %%
signal_labels
# Out:
# ['EEG Fp1',
#  'EEG Fp2',
#  'EEG F3',
#  'EEG F4',
#  'EEG F7',
#  'EEG F8',
#  'EEG T3',
#  'EEG T4',
#  'EEG C3',
#  'EEG C4',
#  'EEG T5',
#  'EEG T6',
#  'EEG P3',
#  'EEG P4',
#  'EEG O1',
#  'EEG O2',
#  'EEG Fz',
#  'EEG Cz',
#  'EEG Pz',
#  'EEG A2-A1',
#  'ECG ECG']

# %%
for i in range(len(sigbufs)):
    plt.plot(sigbufs[i,1:3000])
    plt.show()

# %%
len(sigbufs[1,:])
# Out:
# 31000

# %%
size_sig=sigbufs.shape
print(size_sig[1])
index=np.linspace(0,size_sig[1],size_sig[1])
#print(index)
time = 1/500*index
print(time)
# Out:
# 31000
# [0.00000000e+00 2.00006452e-03 4.00012904e-03 ... 6.19959999e+01
#  6.19979999e+01 6.20000000e+01]

# %%
time
# Out:
# array([0.00000000e+00, 2.00006452e-03, 4.00012904e-03, ...,
#        6.19959999e+01, 6.19979999e+01, 6.20000000e+01])

# %%
plt.plot(time,sigbufs[1,:])
plt.show()

# %%
for i in range(len(sigbufs)):
    plt.plot(time,sigbufs[i,:])
    plt.show()

# %%
sigbufs
# Out:
# array([[ 4.47604913e+00,  1.20802117e+00, -2.54600773e+00, ...,
#         -4.13607233e-04, -4.13607233e-04, -4.13607233e-04],
#        [-2.74030294e+00, -3.30875398e+00, -3.70825978e+00, ...,
#         -1.40245823e-03, -1.40245823e-03, -1.40245823e-03],
#        [-2.50173872e+00, -4.41783471e+00, -6.41085425e+00, ...,
#          2.52872511e-05,  2.52872511e-05,  2.52872511e-05],
#        ...,
#        [ 8.48305957e-01,  4.52614272e-01, -1.03927692e-01, ...,
#         -9.83513695e-04, -9.83513695e-04, -9.83513695e-04],
#        [ 9.30096361e-02, -2.64323612e-01, -4.21048721e-01, ...,
#          2.28371710e-04,  2.28371710e-04,  2.28371710e-04],
#        [-8.46279094e-03, -8.37301808e-03, -8.47401254e-03, ...,
#          9.52217899e-06,  9.52217899e-06,  9.52217899e-06]])

# %%
len(time)
# Out:
# 31000

# %%
time[30999]
# Out:
# 62.0

# %%
time
# Out:
# array([0.00000000e+00, 2.00006452e-03, 4.00012904e-03, ...,
#        6.19959999e+01, 6.19979999e+01, 6.20000000e+01])

# %%
df = pd.read_csv('file00_1.csv')

# %%
df.iloc[0].mean()
# Out:
# 0.0489066549283825

# %%
mean00_1= []
for i in range(len(signal_labels)):
    mean00_1.append(df.iloc[i].mean())
    print('The mean of {} is {}'.format(i,mean))
# Out:
# The mean of 0 is 0.0013439430737610288
# The mean of 1 is 0.0013439430737610288
# The mean of 2 is 0.0013439430737610288
# The mean of 3 is 0.0013439430737610288
# The mean of 4 is 0.0013439430737610288
# The mean of 5 is 0.0013439430737610288
# The mean of 6 is 0.0013439430737610288
# The mean of 7 is 0.0013439430737610288
# The mean of 8 is 0.0013439430737610288
# The mean of 9 is 0.0013439430737610288
# The mean of 10 is 0.0013439430737610288
# The mean of 11 is 0.0013439430737610288
# The mean of 12 is 0.0013439430737610288
# The mean of 13 is 0.0013439430737610288
# The mean of 14 is 0.0013439430737610288
# The mean of 15 is 0.0013439430737610288
# The mean of 16 is 0.0013439430737610288
# The mean of 17 is 0.0013439430737610288
# The mean of 18 is 0.0013439430737610288
# The mean of 19 is 0.0013439430737610288
# The mean of 20 is 0.0013439430737610288

# %%
mean00_1 = np.array(mean00_1)

# %%
mean00_1
# Out:
# array([ 0.04890665, -0.05080987,  0.06961822,  0.0919148 ,  0.03268288,
#         0.02956675, -0.02544544,  0.05476763,  0.05606951,  0.07525976,
#         0.02167824,  0.03802292,  0.0210762 ,  0.00757334,  0.04973209,
#         0.00696335,  0.09880764,  0.01401732,  0.00684079,  0.01686718,
#         0.00134394])

# %%
std00_1 = []
for i in range(len(sigbufs)):
    std00_1.append(df.iloc[i].std())

# %%
std00_1 = np.array(std00_1)

# %%
df.iloc[0].std()
# Out:
# 9.18627603555991
